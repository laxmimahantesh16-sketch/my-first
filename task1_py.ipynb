# %% [markdown]
# <a href="https://colab.research.google.com/github/laxmimahantesh16-sketch/my-first/blob/main/task1_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

data = np.array([12, 15, 20, 20, 25, 30, 35, 40])
print(data)
# Out:
# [12 15 20 20 25 30 35 40]

# %%
import numpy as np

data = np.array([12, 15, 20, 20, 25, 30, 35, 40])
data.size
# Out:
# 8

# %%
import numpy as np

data = np.array([12, 15, 20, 20, 25, 30, 35, 40])
data.dtype
# Out:
# dtype('int64')

# %%
import numpy as np

data = np.array([12, 15, 20, 20, 25, 30, 35, 40])
data.shape
# Out:
# (8,)
