# %% [markdown]
# <a href="https://colab.research.google.com/github/laxmimahantesh16-sketch/my-first/blob/main/task5_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

data = np.array([12, 15, 20, 20, 25, 30, 35, 40])
highest = np.max(data)
lowest = np.min(data)

print("Highest marks:", highest)
print("Lowest marks:", lowest)
# Out:
# Highest marks: 40
# Lowest marks: 12

# %%
import numpy as np

data = np.array([12, 15, 20, 20, 25, 30, 35, 40])
pass_count = np.sum(data >= 20)
print("Number of pass students:", pass_count)
# Out:
# Number of pass students: 6

# %%
import numpy as np

data = np.array([12, 15, 20, 20, 25, 30, 35, 40])
average = np.mean(data)
print("Average marks:", average)
# Out:
# Average marks: 24.625

# %%
import numpy as np

data = np.array([12, 15, 20, 20, 25, 30, 35, 40])
if average < 20:
    performance = "Poor"
elif 20 <= average < 30:
    performance = "Average"
else:
    performance = "Good"

print("Class performance:", performance)
# Out:
# Class performance: Average
