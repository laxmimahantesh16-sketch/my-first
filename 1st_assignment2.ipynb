# %% [markdown]
# <a href="https://colab.research.google.com/github/laxmimahantesh16-sketch/my-first/blob/main/1st_assignment2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def check_attendance(login_time):
    if login_time < 9.30:
        return "Present"
    elif 9.30 <= login_time <= 10.00:
        return "Late"
    else:
        return "Absent"
